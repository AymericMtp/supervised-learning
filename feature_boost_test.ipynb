# %%
import pandas as pd
income_df = pd.read_csv("income_cleaned.csv")

# %%
income_df['estimation_carriere_age'] = income_df['age'] - 10 - income_df['education-num']
income_df.sample(25)
# Out:
#        age         workclass     education  education-num  \
# 43501   43         Local-gov       Masters             14
# 12070   25           Private  Some-college             10
# 26314   35           Private     Bachelors             13
# 9230    28           Private          10th              6
# 40793   38           Private       HS-grad              9
# 9317    25           Private       HS-grad              9
# 23341   28           Private  Some-college             10
# 45027   42       Federal-gov  Some-college             10
# 38486   38           Private     Bachelors             13
# 7662    36           Private          11th              7
# 22669   33  Self-emp-not-inc     Bachelors             13
# 15168   54  Self-emp-not-inc     Bachelors             13
# 33832   30           Private       1st-4th              2
# 25408   21           Private       HS-grad              9
# 27709   41           Private       HS-grad              9
# 31805   34         Local-gov          11th              7
# 26356   47       Federal-gov     Assoc-voc             11
# 261     34           Private    Assoc-acdm             12
# 29640   19           Private  Some-college             10
# 5004    25           Private       HS-grad              9
# 19085   18           Private          11th              7
# 39866   34           Private    Assoc-acdm             12
# 34721   54  Self-emp-not-inc       HS-grad              9
# 23035   20         Local-gov       HS-grad              9
# 32615   33         Local-gov     Bachelors             13
#
#               marital-status        occupation    relationship   race     sex  \
# 43501  Married-spouse-absent    Prof-specialty       Unmarried  White  Female
# 12070     Married-civ-spouse             Sales         Husband  White    Male
# 26314     Married-civ-spouse   Exec-managerial         Husband  White    Male
# 9230      Married-civ-spouse      Craft-repair            Wife  Other  Female
# 40793     Married-civ-spouse      Craft-repair         Husband  White    Male
# 9317      Married-civ-spouse             Sales         Husband  White    Male
# 23341          Never-married   Exec-managerial   Not-in-family  Black  Female
# 45027     Married-civ-spouse      Adm-clerical         Husband  White    Male
# 38486     Married-civ-spouse      Tech-support         Husband  White    Male
# 7662      Married-civ-spouse  Transport-moving         Husband  White    Male
# 22669     Married-civ-spouse    Prof-specialty            Wife  White  Female
# 15168               Divorced   Exec-managerial   Not-in-family  White    Male
# 33832              Separated   Priv-house-serv  Other-relative  White  Female
# 25408          Never-married     Other-service       Own-child  White  Female
# 27709     Married-civ-spouse      Craft-repair         Husband  White    Male
# 31805              Separated     Other-service       Unmarried  Black  Female
# 26356     Married-civ-spouse      Adm-clerical            Wife  White  Female
# 261                 Divorced             Sales       Unmarried  Black  Female
# 29640          Never-married     Other-service       Own-child  White    Male
# 5004           Never-married      Adm-clerical       Own-child  White  Female
# 19085          Never-married     Other-service       Own-child  White    Male
# 39866     Married-civ-spouse             Sales         Husband  White    Male
# 34721     Married-civ-spouse             Sales         Husband  White    Male
# 23035          Never-married     Other-service       Unmarried  Black  Female
# 32615     Married-civ-spouse             Sales         Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country  income  \
# 43501          7430             0              60  United-States       1
# 12070             0             0              50  United-States       0
# 26314             0             0              40  United-States       1
# 9230              0             0              48      Guatemala       0
# 40793             0             0              40  United-States       1
# 9317              0             0              40  United-States       0
# 23341             0             0              45        Jamaica       0
# 45027             0             0              40  United-States       0
# 38486             0             0              45  United-States       0
# 7662              0             0              43  United-States       0
# 22669             0             0              50  United-States       1
# 15168             0             0              50  United-States       0
# 33832             0             0              30         Mexico       0
# 25408             0             0              40  United-States       0
# 27709             0             0              60  United-States       1
# 31805             0             0              40  United-States       0
# 26356             0             0              35  United-States       0
# 261               0             0              45  United-States       0
# 29640             0             0              14  United-States       0
# 5004              0             0              40  United-States       0
# 19085             0             0              12  United-States       0
# 39866             0             0              50  United-States       1
# 34721             0             0              50  United-States       1
# 23035             0             0              40  United-States       0
# 32615             0             0              50  United-States       0
#
#        estimation_carriere_age
# 43501                       19
# 12070                        5
# 26314                       12
# 9230                        12
# 40793                       19
# 9317                         6
# 23341                        8
# 45027                       22
# 38486                       15
# 7662                        19
# 22669                       10
# 15168                       31
# 33832                       18
# 25408                        2
# 27709                       22
# 31805                       17
# 26356                       26
# 261                         12
# 29640                       -1
# 5004                         6
# 19085                        1
# 39866                       12
# 34721                       35
# 23035                        1
# 32615                       10

# %%
numerical_features = ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week', 'estimation_carriere_age']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
plt.figure(figsize=(10, 8))
correlation_matrix = income_df[numerical_features + ['income']].corr()

sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', 
            square=True, linewidths=1, cbar_kws={"shrink": 0.8})
plt.title('Correlation Matrix: Numerical Features + Income', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('correlation_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

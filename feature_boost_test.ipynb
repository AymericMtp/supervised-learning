# %%
import pandas as pd
import numpy as np
income_df = pd.read_csv("income_cleaned.csv")

# %%
income_df['estimation_carriere_age'] = income_df['age'] - 10 - income_df['education-num']
income_df['is_married'] = income_df['marital-status'].apply(lambda x: 1 if 'Married' in x else 0)
income_df['maried_education_experience'] = income_df['education-num'] * income_df['age'] * income_df['is_married']
income_df.sample(25)
# Out:
#        age         workclass     education  education-num      marital-status  \
# 30815   58           Private     Bachelors             13            Divorced
# 22861   22           Private       HS-grad              9       Never-married
# 26343   35           Private       HS-grad              9  Married-civ-spouse
# 33506   23           Private  Some-college             10       Never-married
# 22827   17           Private          10th              6       Never-married
# 12750   20           Private       HS-grad              9       Never-married
# 44726   18           Private  Some-college             10       Never-married
# 45010   43  Self-emp-not-inc     Bachelors             13  Married-civ-spouse
# 12228   36           Private          10th              6  Married-civ-spouse
# 24970   45           Private  Some-college             10  Married-civ-spouse
# 22229   40           Private     Bachelors             13  Married-civ-spouse
# 6774    48           Private     Bachelors             13            Divorced
# 31354   36           Private       HS-grad              9  Married-civ-spouse
# 13812   34           Private     Bachelors             13       Never-married
# 13237   53       Federal-gov       HS-grad              9             Widowed
# 37320   39           Private  Some-college             10            Divorced
# 6138    58           Private          11th              7  Married-civ-spouse
# 27962   50           Private       HS-grad              9  Married-civ-spouse
# 16248   21           Private  Some-college             10       Never-married
# 37774   66      Self-emp-inc  Some-college             10  Married-civ-spouse
# 18094   31           Private       HS-grad              9  Married-civ-spouse
# 12497   46           Private     Bachelors             13  Married-civ-spouse
# 6758    35           Private       HS-grad              9            Divorced
# 33564   81           Private          12th              8             Widowed
# 5656    27           Private     Bachelors             13       Never-married
#
#               occupation    relationship   race     sex  capital-gain  \
# 30815    Exec-managerial   Not-in-family  White    Male             0
# 22861       Adm-clerical       Own-child  White  Female             0
# 26343       Craft-repair         Husband  White    Male             0
# 33506      Other-service       Own-child  White    Male             0
# 22827      Other-service       Own-child  White    Male             0
# 12750       Adm-clerical       Own-child  White    Male             0
# 44726              Sales  Other-relative  White  Female             0
# 45010              Sales         Husband  White    Male             0
# 12228       Craft-repair         Husband  White    Male             0
# 24970    Exec-managerial         Husband  White    Male             0
# 22229    Exec-managerial         Husband  White    Male             0
# 6774        Adm-clerical   Not-in-family  White    Male             0
# 31354  Machine-op-inspct         Husband  White    Male             0
# 13812              Sales   Not-in-family  White  Female             0
# 13237    Exec-managerial   Not-in-family  White  Female             0
# 37320    Exec-managerial       Unmarried  White  Female             0
# 6138        Adm-clerical         Husband  White    Male             0
# 27962       Craft-repair         Husband  White    Male             0
# 16248       Adm-clerical       Own-child  White  Female             0
# 37774              Sales         Husband  White    Male             0
# 18094       Craft-repair         Husband  White    Male             0
# 12497    Exec-managerial         Husband  White    Male          7688
# 6758   Handlers-cleaners   Not-in-family  White    Male             0
# 33564              Sales   Not-in-family  White  Female             0
# 5656               Sales   Not-in-family  Black  Female             0
#
#        capital-loss  hours-per-week native-country  income  \
# 30815             0              65  United-States       1
# 22861             0              40  United-States       0
# 26343          2377              40  United-States       0
# 33506             0              40  United-States       0
# 22827             0              15  United-States       0
# 12750             0              40  United-States       0
# 44726             0              15  United-States       0
# 45010             0              40  United-States       1
# 12228             0              40  United-States       0
# 24970             0              40  United-States       0
# 22229          1977              50  United-States       1
# 6774              0              40  United-States       0
# 31354             0              40  United-States       0
# 13812             0              40  United-States       0
# 13237             0              58  United-States       0
# 37320             0              15  United-States       0
# 6138              0              48  United-States       0
# 27962             0              40  United-States       0
# 16248             0              40  United-States       0
# 37774             0              50  United-States       0
# 18094             0              40  United-States       0
# 12497             0              40  United-States       1
# 6758              0              25  United-States       0
# 33564             0              30  United-States       0
# 5656              0              40  United-States       0
#
#        estimation_carriere_age  is_married  maried_education_experience
# 30815                       35           0                            0
# 22861                        3           0                            0
# 26343                       16           1                          315
# 33506                        3           0                            0
# 22827                        1           0                            0
# 12750                        1           0                            0
# 44726                       -2           0                            0
# 45010                       20           1                          559
# 12228                       20           1                          216
# 24970                       25           1                          450
# 22229                       17           1                          520
# 6774                        25           0                            0
# 31354                       17           1                          324
# 13812                       11           0                            0
# 13237                       34           0                            0
# 37320                       19           0                            0
# 6138                        41           1                          406
# 27962                       31           1                          450
# 16248                        1           0                            0
# 37774                       46           1                          660
# 18094                       12           1                          279
# 12497                       23           1                          598
# 6758                        16           0                            0
# 33564                       63           0                            0
# 5656                         4           0                            0

# %%
numerical_features = ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week', 'estimation_carriere_age', 'is_married', 'maried_education_experience']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
plt.figure(figsize=(10, 8))
correlation_matrix = income_df[numerical_features + ['income']].corr()

sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', 
            square=True, linewidths=1, cbar_kws={"shrink": 0.8})
plt.title('Correlation Matrix: Numerical Features + Income', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('correlation_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
income_df.to_csv("income_boosted.csv", index=False)
